# %%
import pandas as pd
import codecs

# %%
# メモリ削減
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
# csvを読み込みデータフレームに変換
df = {}
with codecs.open("../../data/input/useVideos.csv", "r", "utf-8", "ignore") as file:
    df = pd.read_table(file, delimiter=",")

# %%
df
# Out:
#        Unnamed: 0     video_id trending_date  \
# 0               0  5ugKfHgsmYw      18.07.02
# 1               1  5ugKfHgsmYw      18.07.02
# 2               2  5ugKfHgsmYw      18.07.02
# 3              12  5ugKfHgsmYw      18.08.02
# 4              13  5ugKfHgsmYw      18.08.02
# ...           ...          ...           ...
# 167580      23504  f4NWt_O2vBg      18.14.06
# 167581      23505  0EaUDUgczQ0      18.14.06
# 167582      23506  niKln6fWWrY      18.14.06
# 167583      23507  EmoDAd0eYiM      18.14.06
# 167584      23508  YdGVl1-WEgg      18.14.06
#
#                                                     title   channel_title  \
# 0                                      陸自ヘリ、垂直に落下＝路上の車が撮影      時事通信映像センター
# 1                                      陸自ヘリ、垂直に落下＝路上の車が撮影      時事通信映像センター
# 2                                      陸自ヘリ、垂直に落下＝路上の車が撮影      時事通信映像センター
# 3                                      陸自ヘリ、垂直に落下＝路上の車が撮影      時事通信映像センター
# 4                                      陸自ヘリ、垂直に落下＝路上の車が撮影      時事通信映像センター
# ...                                                   ...             ...
# 167580                  まらしぃ（marasy） piano live tour 2018         marasy8
# 167581              【ポケモンGO】カイオーガ５連戦＋１戦してたら思わぬ結果になった【色違い】         はっちゃんねる
# 167582  The Youth Board Asks #1 – How Does The Report ...       Supercell
# 167583  Harke Haldar | किन हुन दिएनन् खम्बेले देउतिको ...  Kantipur TV HD
# 167584                      【あるある】現役アイドルとあるある再現したら闇が深すぎた…       おこさまぷれ〜と。
#
#         category_id              publish_time  \
# 0              25.0  2018-02-06T03:04:37.000Z
# 1              25.0  2018-02-06T03:04:37.000Z
# 2              25.0  2018-02-06T03:04:37.000Z
# 3              25.0  2018-02-06T03:04:37.000Z
# 4              25.0  2018-02-06T03:04:37.000Z
# ...             ...                       ...
# 167580         10.0  2018-06-13T10:46:36.000Z
# 167581         20.0  2018-06-13T10:00:00.000Z
# 167582         29.0  2018-06-13T10:33:56.000Z
# 167583         23.0  2018-06-13T14:15:01.000Z
# 167584         24.0  2018-06-13T11:00:03.000Z
#
#                                                      tags     views    likes  \
# 0       事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  188085.0    591.0
# 1       事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  188085.0    591.0
# 2       事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  188085.0    591.0
# 3       事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  312569.0    807.0
# 4       事故|"佐賀"|"佐賀県"|"ヘリコプター"|"ヘリ"|"自衛隊"|"墜落"|"落下"|"現...  312569.0    807.0
# ...                                                   ...       ...      ...
# 167580                       ピアノ|"piano"|"marasy8"|"まらしぃ"   35735.0   1959.0
# 167581  ポケモンgo|"ポケモン"|"GO"|"はつだ"|"はっちゃんねる"|"実況"|"攻略"|"...   38214.0    551.0
# 167582                                             [none]  640996.0  10105.0
# 167583  nepali comedy video|"nepali comedy serial"|"ne...  134920.0   3766.0
# 167584  おこぷれ|"おこさまぷれ〜と。"|"YouTuber"|"JK"|"女子高生"|"おこさまぷ...   17237.0    369.0
#
#         dislikes  comment_count  \
# 0          189.0            0.0
# 1          189.0            0.0
# 2          189.0            0.0
# 3          250.0            0.0
# 4          250.0            0.0
# ...          ...            ...
# 167580       9.0          311.0
# 167581      75.0           90.0
# 167582    1034.0         1961.0
# 167583     180.0          408.0
# 167584      29.0           93.0
#
#                                         thumbnail_link comments_disabled  \
# 0       https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg              True
# 1       https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg              True
# 2       https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg              True
# 3       https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg              True
# 4       https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg              True
# ...                                                ...               ...
# 167580  https://i.ytimg.com/vi/f4NWt_O2vBg/default.jpg             False
# 167581  https://i.ytimg.com/vi/0EaUDUgczQ0/default.jpg             False
# 167582  https://i.ytimg.com/vi/niKln6fWWrY/default.jpg             False
# 167583  https://i.ytimg.com/vi/EmoDAd0eYiM/default.jpg             False
# 167584  https://i.ytimg.com/vi/YdGVl1-WEgg/default.jpg             False
#
#        ratings_disabled video_error_or_removed  \
# 0                 False                  False
# 1                 False                  False
# 2                 False                  False
# 3                 False                  False
# 4                 False                  False
# ...                 ...                    ...
# 167580            False                  False
# 167581            False                  False
# 167582            False                  False
# 167583            False                  False
# 167584            False                  False
#
#                                               description  \
# 0       佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...
# 1       佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...
# 2       佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...
# 3       佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...
# 4       佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近...
# ...                                                   ...
# 167580  まらしぃです。今年も秋にライブツアーをやらせて頂けることになりました。とても嬉しいです。色々...
# 167581  先日のニキのホウオウの色違い。悔しかった・・・！！！ので一人でカイオーガ行きまくって来ました...
# 167582  In connection with this year's Stand Up To Bul...
# 167583  Nepali Comedy Video - Harke Haldar | Popular N...
# 167584  新生YouTuber研究会BYSさん: https://www.youtube.com/ch...
#
#                       channel_id  subscriber_count
# 0       UCNLxBzguoGLqXWA8_BtHSHA           72700.0
# 1       UCNLxBzguoGLqXWA8_BtHSHA           74900.0
# 2       UCNLxBzguoGLqXWA8_BtHSHA           75100.0
# 3       UCNLxBzguoGLqXWA8_BtHSHA           72700.0
# 4       UCNLxBzguoGLqXWA8_BtHSHA           74900.0
# ...                          ...               ...
# 167580  UCcvLSRIWJIAGFDyWtzkbiHA         1620000.0
# 167581  UC6z9hHYTAV8eW--F4JndgiQ          113000.0
# 167582  UCXO2ZE-H4ZVjJDjTuQzv-Bw          637000.0
# 167583  UC3yDoaqQzOd1bNP74ZrGPTA         1800000.0
# 167584  UCJhEEqGP9Mxfb5SJNq7aOmQ          338000.0
#
# [167585 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'video_id', 'trending_date', 'title', 'channel_title',
#        'category_id', 'publish_time', 'tags', 'views', 'likes', 'dislikes',
#        'comment_count', 'thumbnail_link', 'comments_disabled',
#        'ratings_disabled', 'video_error_or_removed', 'description',
#        'channel_id', 'subscriber_count'],
#       dtype='object')

# %% [markdown]
# # カテゴリIDのOne Hot Encoding化
