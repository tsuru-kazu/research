# %%
# ライブラリ読み込み
import pandas as pd
import codecs
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
# メモリ削減
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
# csvを読み込みデータフレームに変換
df = {}
with codecs.open("../data/input/JPvideos.csv", "r", "utf-8", "ignore") as file:
    df = pd.read_table(file, delimiter=",")
    df = reduce_mem_usage(df)
# Out:
# Memory usage of dataframe is 2.09 MB
# Memory usage after optimization is: 4.30 MB
# Decreased by -105.1%

# %% [markdown]
# ## 基本的なデータ操作

# %% [markdown]
# colomns = list(df.columns)
# for c in colomns:
#     print(c)
# print(len(colomns))

# %%
print(df.shape)
print(df.dtypes)
print(df.info())
print(df.isna())
# Out:
# (20523, 16)
# video_id                  category
# trending_date             category
# title                     category
# channel_title             category
# category_id                   int8
# publish_time              category
# tags                      category
# views                        int32
# likes                        int32
# dislikes                     int32
# comment_count                int32
# thumbnail_link            category
# comments_disabled          float16
# ratings_disabled           float16
# video_error_or_removed     float16
# description               category
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20523 entries, 0 to 20522
# Data columns (total 16 columns):
# video_id                  20523 non-null category
# trending_date             20523 non-null category
# title                     20523 non-null category
# channel_title             20523 non-null category
# category_id               20523 non-null int8
# publish_time              20523 non-null category
# tags                      20523 non-null category
# views                     20523 non-null int32
# likes                     20523 non-null int32
# dislikes                  20523 non-null int32
# comment_count             20523 non-null int32
# thumbnail_link            20523 non-null category
# comments_disabled         20523 non-null float16
# ratings_disabled          20523 non-null float16
# video_error_or_removed    20523 non-null float16
# description               18399 non-null category
# dtypes: category(8), float16(3), int32(4), int8(1)
# memory usage: 4.3 MB
# None
#        video_id  trending_date  title  channel_title  category_id  \
# 0         False          False  False          False        False
# 1         False          False  False          False        False
# 2         False          False  False          False        False
# 3         False          False  False          False        False
# 4         False          False  False          False        False
# ...         ...            ...    ...            ...          ...
# 20518     False          False  False          False        False
# 20519     False          False  False          False        False
# 20520     False          False  False          False        False
# 20521     False          False  False          False        False
# 20522     False          False  False          False        False
#
#        publish_time   tags  views  likes  dislikes  comment_count  \
# 0             False  False  False  False     False          False
# 1             False  False  False  False     False          False
# 2             False  False  False  False     False          False
# 3             False  False  False  False     False          False
# 4             False  False  False  False     False          False
# ...             ...    ...    ...    ...       ...            ...
# 20518         False  False  False  False     False          False
# 20519         False  False  False  False     False          False
# 20520         False  False  False  False     False          False
# 20521         False  False  False  False     False          False
# 20522         False  False  False  False     False          False
#
#        thumbnail_link  comments_disabled  ratings_disabled  \
# 0               False              False             False
# 1               False              False             False
# 2               False              False             False
# 3               False              False             False
# 4               False              False             False
# ...               ...                ...               ...
# 20518           False              False             False
# 20519           False              False             False
# 20520           False              False             False
# 20521           False              False             False
# 20522           False              False             False
#
#        video_error_or_removed  description
# 0                       False        False
# 1                       False         True
# 2                       False         True
# 3                       False        False
# 4                       False        False
# ...                       ...          ...
# 20518                   False        False
# 20519                   False        False
# 20520                   False        False
# 20521                   False        False
# 20522                   False        False
#
# [20523 rows x 16 columns]

# %% [markdown]
# ## カラムごとのユニーク数とユニーク値の表示

# %%
for c, v in df.iteritems():
    num_uniques = v.nunique()
    print ('{name}: {num_unique}'.format(name=c, num_unique=num_uniques))
    print (v.unique())
    print ('\n')
# Out:
# video_id: 12912
# [佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近..., NaN, 東京ディズニーリゾートの元キャストが暴露した秘密5選\n\nかたまりクリエイトさま\n【検証..., 家に帰ってきたサラリーマンのじゅん（安田顕）は、玄関で血を出して倒れている妻ちえ（榮倉奈々）..., Twitter始めました！\n\n登録よろしくお願いします＾＾\nhttps://twitt..., ..., まらしぃです。今年も秋にライブツアーをやらせて頂けることになりました。とても嬉しいです。色々..., 先日のニキのホウオウの色違い。悔しかった・・・！！！ので一人でカイオーガ行きまくって来ました..., In connection with this year's Stand Up To Bul..., Nepali Comedy Video - Harke Haldar | Popular N..., 新生YouTuber研究会BYSさん: https://www.youtube.com/ch...]
# Length: 10744
# Categories (10743, object): [佐賀県神埼市の民家に墜落した陸上自衛隊のＡＨ６４Ｄ戦闘ヘリコプターが垂直に落下する様子を、近..., 東京ディズニーリゾートの元キャストが暴露した秘密5選\n\nかたまりクリエイトさま\n【検証..., 家に帰ってきたサラリーマンのじゅん（安田顕）は、玄関で血を出して倒れている妻ちえ（榮倉奈々）..., Twitter始めました！\n\n登録よろしくお願いします＾＾\nhttps://twitt..., ..., 先日のニキのホウオウの色違い。悔しかった・・・！！！ので一人でカイオーガ行きまくって来ました..., In connection with this year's Stand Up To Bul..., Nepali Comedy Video - Harke Haldar | Popular N..., 新生YouTuber研究会BYSさん: https://www.youtube.com/ch...]

# %% [markdown]
# ## 統計量の表示

# %%
# %%time
stats = []
for col in df.columns:
    stats.append((col,
                  df[col].nunique(),
                  df[col].value_counts().index[0],
                  df[col].value_counts().values[0],
                  df[col].isnull().sum() * 100 / df.shape[0],
                  df[col].value_counts(normalize=True, dropna=False).values[0] * 100,
                  df[col].dtype))
stats_df = pd.DataFrame(stats, columns=['Feature', 'Unique values', 'Most frequent item', 'Freuquence of most frequent item', 'Percentage of missing values', 'Percentage of values in the biggest category', 'Type'])
stats_df.sort_values('Percentage of missing values', ascending=False)
# Out:
# CPU times: user 199 ms, sys: 10.1 ms, total: 209 ms
# Wall time: 246 ms
#                    Feature  Unique values  \
# 15             description          10743
# 0                 video_id          12912
# 1            trending_date            122
# 2                    title          13087
# 3            channel_title           4649
# 4              category_id             15
# 5             publish_time          12505
# 6                     tags           8761
# 7                    views          13928
# 8                    likes           5047
# 9                 dislikes           1542
# 10           comment_count           2437
# 11          thumbnail_link          13093
# 12       comments_disabled              2
# 13        ratings_disabled              2
# 14  video_error_or_removed              2
#
#                                 Most frequent item  \
# 15                                              説明
# 0                                           #NAME?
# 1                                         18.28.04
# 2                                【吹いたら負け】話題の面白い画像集
# 3                                           DHCテレビ
# 4                                               24
# 5                         2018-02-06T08:00:01.000Z
# 6                                           [none]
# 7                                           105112
# 8                                                0
# 9                                                0
# 10                                               0
# 11  https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg
# 12                                               0
# 13                                               0
# 14                                               0
#
#     Freuquence of most frequent item  Percentage of missing values  \
# 15                                94                     10.349364
# 0                                282                      0.000000
# 1                                199                      0.000000
# 2                                 17                      0.000000
# 3                                169                      0.000000
# 4                               6259                      0.000000
# 5                                 12                      0.000000
# 6                               3200                      0.000000
# 7                                  6                      0.000000
# 8                               1392                      0.000000
# 9                               1679                      0.000000
# 10                              1816                      0.000000
# 11                                 8                      0.000000
# 12                             19109                      0.000000
# 13                             19133                      0.000000
# 14                             20511                      0.000000
#
#     Percentage of values in the biggest category      Type
# 15                                     10.349364  category
# 0                                       1.374068  category
# 1                                       0.969644  category
# 2                                       0.082834  category
# 3                                       0.823466  category
# 4                                      30.497491      int8
# 5                                       0.058471  category
# 6                                      15.592262  category
# 7                                       0.029235     int32
# 8                                       6.782634     int32
# 9                                       8.181065     int32
# 10                                      8.848609     int32
# 11                                      0.038981  category
# 12                                     93.110169   float16
# 13                                     93.227111   float16
# 14                                     99.941529   float16

# %% [markdown]
# ## 全カラムのヒストグラム

# %%
df.hist(bins=50, figsize=(80,60))
plt.show()

# %% [markdown]
# ## 散布図

# %%
plt.figure(figsize=(15, 5))
plt.scatter(df['views'], df['comment_count'])
plt.title('title')
plt.xlabel('views')
plt.ylabel('comment_count')
plt.show()

# %% [markdown]
# ## 欠損値をヒートマップで可視化

# %%
plt.figure(figsize=(18,9))
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ## 特徴量同士の相関をヒートマップで可視化

# %%
fig, ax = plt.subplots(figsize=(12, 9)) 
sns.heatmap(df.corr(), square=True, vmax=1, vmin=-1, center=0)

# %% [markdown]
# ## ターゲットとその他の特緒量との相関

# %%
df.corr()["views"].sort_values()
# Out:
# category_id              -0.032998
# comments_disabled        -0.020017
# ratings_disabled         -0.015676
# video_error_or_removed   -0.001935
# dislikes                  0.804670
# comment_count             0.843851
# likes                     0.850367
# views                     1.000000
# Name: views, dtype: float64

# %% [markdown]
# ## 分類タスクにおけるターゲットの相関

# %%
df['views'].value_counts()
# Out:
# 105112    6
# 2869      6
# 6499      6
# 9387      5
# 8051      5
#          ..
# 14942     1
# 174118    1
# 426585    1
# 31318     1
# 13831     1
# Name: views, Length: 13928, dtype: int64

# %%
numerical_feats = df.dtypes[df.dtypes != "category"].index
categorical_feats = df.dtypes[df.dtypes == "category"].index

# %%
numerical_feats
# Out:
# Index(['category_id', 'views', 'likes', 'dislikes', 'comment_count',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed'],
#       dtype='object')

# %%
categorical_feats
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'publish_time',
#        'tags', 'thumbnail_link', 'description'],
#       dtype='object')

# %% [markdown]
# ## 欠損地の確認

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                         Total   Percent
# description              2124  0.103494
# video_error_or_removed      0  0.000000
# ratings_disabled            0  0.000000
# comments_disabled           0  0.000000
# thumbnail_link              0  0.000000
# comment_count               0  0.000000
# dislikes                    0  0.000000
# likes                       0  0.000000
# views                       0  0.000000
# tags                        0  0.000000
# publish_time                0  0.000000
# category_id                 0  0.000000
# channel_title               0  0.000000
# title                       0  0.000000
# trending_date               0  0.000000
# video_id                    0  0.000000

# %% [markdown]
# ## Numerical Features

# %%
df.describe()
# Out:
#         category_id         views         likes       dislikes  comment_count
# count  20523.000000  2.052300e+04  2.052300e+04   20523.000000   20523.000000
# mean      19.807533  2.620215e+05  8.059587e+03     366.823613    1196.077864
# std        6.655895  1.294938e+06  8.384837e+04    2658.598540   14943.608305
# min        1.000000  7.980000e+02  0.000000e+00       0.000000       0.000000
# 25%       17.000000  1.710000e+04  1.210000e+02       9.000000      19.000000
# 50%       22.000000  6.408400e+04  6.480000e+02      43.000000     133.000000
# 75%       24.000000  1.833670e+05  2.303000e+03     178.000000     488.000000
# max       29.000000  6.279639e+07  4.470923e+06  119053.000000  905925.000000

# %%
nr_rows = 12 #図を表示する際の行数
nr_cols = 3 #図を表示する際の列数
#nr_rows * nr_colsがカラム数を超えるように設定。

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3))

li_num_feats = list(numerical_feats)
li_not_plot = ["category_id", "comments_disabled", "ratings_disabled"]
li_plot_num_feats = [c for c in list(numerical_feats) if c not in li_not_plot]
target = "views"

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c
        if i < len(li_plot_num_feats):
            sns.regplot(df[li_plot_num_feats[i]], df[target], ax = axs[r][c])
            stp = stats.pearsonr(df[li_plot_num_feats[i]], df[target])
            str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
            axs[r][c].set_title(str_title,fontsize=11)

plt.tight_layout()    
plt.show()

# %% [markdown]
# 上記より、目的変数であるviewsの説明変数は、likes、dislikes、comment_countであることが分かる

# %% [markdown]
# ## Categorical Feature

# %%
for catg in list(categorical_feats) :
    print(df[catg].value_counts())
    print('#'*50)
# Out:
# #NAME?         282
# 5ugKfHgsmYw      8
# geOSYId6tac      8
# KqtWo-4A0LU      8
# bmY9DnNH7rE      6
#               ...
# RKjk0ECXjiQ      1
# RKpjH-O8a6w      1
# RL94v8akYP0      1
# kMSsowUH21E      1
# L94gGziIA5I      1
# Name: video_id, Length: 12912, dtype: int64
# ##################################################
# 18.28.04    199
# 18.04.05    199
# 18.04.04    199
# 18.26.04    198
# 18.15.05    197
#            ...
# 18.07.02    128
# 18.28.03    102
# 18.19.05     92
# 18.20.05     56
# 18.15.03     40
# Name: trending_date, Length: 122, dtype: int64
# ##################################################
# 【吹いたら負け】話題の面白い画像集                            17
# リクエストを即興で弾き語ります！！！                           14
# 陸自ヘリ、垂直に落下＝路上の車が撮影                            8
# 西城秀樹の訃報を江原啓之が予言していた事実が発覚！１０年前の霊視で見えた内容とは？     8
# 【最強の飯テロ】絶対に深夜に見ないでください。                       7
#                                              ..
# イッテＱ  宮川  寒すぎて中岡になってしまうｗｗｗｗｗｗｗ                1
# イッテQ　イモトｗｗスタッフと荷物の取り合いｗｗｗ                     1
# イッテQ　イモト　美しすぎる棚田が全部人工物だったｗｗｗ                  1
# イッテQ 男3人祭り ヘルメットおじさんW                         1
# !t Live Special : The 7th MUGI-BOX SHINee     1
# Name: title, Length: 13087, dtype: int64
# ##################################################
# DHCテレビ           169
# 釣りよかでしょう。        145
# 釣りよか飯            108
# MEGWIN TV         90
# はいじぃ迷作劇場          88
#                 ...
# RSKsports          1
# RY YAS             1
# RYU TUBE           1
# RYU 実況チャンネル        1
# !!8時だよ面白ネタ大集合      1
# Name: channel_title, Length: 4649, dtype: int64
# ##################################################
# 2018-02-06T08:00:01.000Z    12
# 2018-05-31T08:00:02.000Z    12
# 2018-06-10T10:00:00.000Z    11
# 2018-03-01T03:00:01.000Z    11
# 2018-02-15T08:00:01.000Z    10
#                             ..
# 2018-04-18T10:33:22.000Z     1
# 2018-04-18T10:38:01.000Z     1
# 2018-04-18T10:52:52.000Z     1
# 2018-04-18T11:00:02.000Z     1
# 2018-04-13T10:29:15.000Z     1
# Name: publish_time, Length: 12505, dtype: int64
# ##################################################
# [none]                                                                                                                                                                                                                                                          3200
# Fishing|"bassfishing"|"釣り"|"バス釣り"|"ブラックバス"|"ブラックバス釣り"|"ライトショアジギング"|"ショアジギング"|"ジギング"|"佐賀よかでしょう"|"釣りよかでしょう"|"泳がせ釣り"|"アジング"|"エギング"|"佐賀"|"福岡"|"長崎"|"大分"|"熊本"|"宮崎"|"鹿児島"|"九州"|"おかっぱり"|"陸っぱり"|"野池"|"リザーバー"|"クリーク"|"川"|"川バス"|"バスフィッシング"|"春"|"夏"|"秋"|"冬"|"ルアーフィッシング"     145
# 料理|"ブログ"|"エンターテイメント"|"やってみた"|"むねお"|"よーらい"|"佐賀よかでしょう"|"釣りよかでしょう"                                                                                                                                                                                                  108
# よーらい|"佐賀よかでしょう"|"釣りよかでしょう"|"釣り"                                                                                                                                                                                                                                   76
# hajime|"はじめしゃちょー"|"funny"|"crazy"|"japanese"|"はじめ"                                                                                                                                                                                                                69
#                                                                                                                                                                                                                                                                 ...
# アメリカンズパニック|"アメパニ"|"うざたにパイセン"|"うさたにパイセン"|"トミー"|"とみー"|"tommy"|"ホストクラブ"|"ホスト"|"大阪"|"ミナミ"|"クラブシックス"|"clubsix"|"six"|"シックス"|"アイフォーユー"|"aiforyou"|"ai for you"|"club six"|"イケメン"|"シャンパン"|"シャンパンコール"|"ヒップスター"|"魂菌ダイナソーズ"|"早川彰"|"翼"|"リオン"                                  1
# アヤセン|"バイク女子"|"AYA1000RR"|"オートバイ"|"ツーリング"|"CBR1000RR"|"大型バイク"|"スーパースポーツ"|"スポーツバイク"                                                                                                                                                                                  1
# アルティメット人狼|"人狼"|"人狼TLPT"|"ニコニコ超会議"                                                                                                                                                                                                                                  1
# 心霊写真|"ホラー"|"恐怖"|"北の打ち師達"|"ふぇると"|"はるくん"                                                                                                                                                                                                                             1
# 「東京喰種 トーキョーグール：re」ネタバレ169話                                                                                                                                                                                                                                         1
# Name: tags, Length: 8761, dtype: int64
# ##################################################
# https://i.ytimg.com/vi/5ugKfHgsmYw/default.jpg    8
# https://i.ytimg.com/vi/KqtWo-4A0LU/default.jpg    8
# https://i.ytimg.com/vi/geOSYId6tac/default.jpg    8
# https://i.ytimg.com/vi/f9Ggvq_4Jdo/default.jpg    6
# https://i.ytimg.com/vi/gH92h6_0ICs/default.jpg    6
#                                                  ..
# https://i.ytimg.com/vi/ZnQ12S_wr3A/default.jpg    1
# https://i.ytimg.com/vi/Zn4DrHqe_E4/default.jpg    1
# https://i.ytimg.com/vi/ZmStrGraAGo/default.jpg    1
# https://i.ytimg.com/vi/ZlUF1K6Mdp4/default.jpg    1
# https://i.ytimg.com/vi/--Tpfju7HOs/default.jpg    1
# Name: thumbnail_link, Length: 13093, dtype: int64
# ##################################################
# 説明                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                